# %%
import pandas as pd

# %%
data1 = pd.read_csv('../Datasets/2025-05_jagr-cost-export-standard-00001.csv')
data1.head()
# Out:
# C:\Users\diyan\AppData\Local\Temp\ipykernel_39500\1791079654.py:1: DtypeWarning: Columns (28,38,39,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   data1 = pd.read_csv('../Datasets/2025-05_jagr-cost-export-standard-00001.csv')
#   bill_bill_type bill_billing_entity bill_billing_period_end_date  \
# 0    Anniversary                 AWS     2025-06-01T00:00:00.000Z
# 1    Anniversary                 AWS     2025-06-01T00:00:00.000Z
# 2    Anniversary                 AWS     2025-06-01T00:00:00.000Z
# 3    Anniversary                 AWS     2025-06-01T00:00:00.000Z
# 4    Anniversary                 AWS     2025-06-01T00:00:00.000Z
#
#   bill_billing_period_start_date  bill_invoice_id      bill_invoicing_entity  \
# 0       2025-05-01T00:00:00.000Z              NaN  Amazon Web Services, Inc.
# 1       2025-05-01T00:00:00.000Z              NaN  Amazon Web Services, Inc.
# 2       2025-05-01T00:00:00.000Z              NaN  Amazon Web Services, Inc.
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 694489 entries, 0 to 694488
# Columns: 125 entries, bill_bill_type to split_line_item_unused_cost
# dtypes: float64(65), int64(2), object(58)
# memory usage: 662.3+ MB
