# %% [markdown]
# # Profiling project dan operasi AWS yang dikerjakan & digunakan user tech owner

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../cleaned-datasets/data-cleaned-final.csv")
data.head(15)
# Out:
#     line_item_usage_amount  line_item_normalization_factor  \
# 0             1.257487e-03                             0.0
# 1             2.232143e-01                             0.0
# 2             5.442370e-05                             0.0
# 3             5.593500e-06                             0.0
# 4             1.488095e-01                             0.0
# 5             4.208230e-03                             0.0
# 6             1.000000e+00                             1.0
# 7             3.720238e-02                             0.0
# 8             1.810000e+02                             0.0
# 9             3.730000e-08                             0.0
# 10            2.943000e-06                             0.0
# 11            4.293000e-07                             0.0
# 12            6.600000e+01                             0.0
# 13            3.000000e+00                             0.0
# 14            1.000000e+00                             8.0
#
#     line_item_normalized_usage_amount line_item_line_item_type  \
# 0                                 0.0                    Usage
# 1                                 0.0                    Usage
# 2                                 0.0                    Usage
# 3                                 0.0                    Usage
# 4                                 0.0                    Usage
# 5                                 0.0                    Usage
# 6                                 1.0                    Usage
# 7                                 0.0                    Usage
# 8                                 0.0                    Usage
# 9                                 0.0                    Usage
# 10                                0.0                    Usage
# 11                                0.0                    Usage
# 12                                0.0                    Usage
# 13                                0.0                    Usage
# 14                                8.0                    Usage
#
#                 line_item_usage_type      line_item_operation  product_region  \
# 0   APS1-DataTransfer-Regional-Bytes            InterZone-Out  ap-southeast-1
# 1           APS1-EBS:VolumeUsage.gp3         CreateVolume-Gp3  ap-southeast-1
# 2   APS1-DataTransfer-Regional-Bytes             InterZone-In  ap-southeast-1
# 3            APS4-USW1-AWS-Out-Bytes             PublicIP-Out  ap-southeast-3
# 4               APS1-EBS:VolumeUsage             CreateVolume  ap-southeast-1
# 5        APS1-DataTransfer-Out-Bytes             RunInstances  ap-southeast-1
# 6            APS1-BoxUsage:t3a.small             RunInstances  ap-southeast-1
# 7               APS1-EBS:VolumeUsage             CreateVolume  ap-southeast-1
# 8             APS1-EBS:VolumeIOUsage             EBS:IO-Write  ap-southeast-1
# 9        APS1-DataTransfer-Out-Bytes             RunInstances  ap-southeast-1
# 10            APS4-APS1-AWS-In-Bytes              PublicIP-In  ap-southeast-3
# 11           APS1-APN2-AWS-Out-Bytes       ReadCostAllocation  ap-southeast-1
# 12           EU-Requests-Tier2-HTTPS                      GET       eu-west-1
# 13               APS1-Requests-Tier1  InitiateMultipartUpload  ap-southeast-1
# 14          APS1-BoxUsage:t4g.xlarge             RunInstances  ap-southeast-1
#
#          product_to_location     product_from_location product_transfer_type  \
# 0   Asia Pacific (Singapore)  Asia Pacific (Singapore)           IntraRegion
# 1                No Transfer               No Transfer           No Transfer
# 2   Asia Pacific (Singapore)  Asia Pacific (Singapore)           IntraRegion
# 3    US West (N. California)    Asia Pacific (Jakarta)  InterRegion Outbound
# 4                No Transfer               No Transfer           No Transfer
# 5                   External  Asia Pacific (Singapore)          AWS Outbound
# 6                No Transfer               No Transfer           No Transfer
# 7                No Transfer               No Transfer           No Transfer
# 8                No Transfer               No Transfer           No Transfer
# 9                   External  Asia Pacific (Singapore)          AWS Outbound
# 10  Asia Pacific (Singapore)    Asia Pacific (Jakarta)   InterRegion Inbound
# 11      Asia Pacific (Seoul)  Asia Pacific (Singapore)  InterRegion Outbound
# 12               No Transfer               No Transfer           No Transfer
# 13               No Transfer               No Transfer           No Transfer
# 14               No Transfer               No Transfer           No Transfer
#
#     ... pricing_term pricing_unit resource_tags_user_customer  \
# 0   ...     OnDemand           GB                 Kemendikbud
# 1   ...     OnDemand        GB-Mo                 Kemendikbud
# 2   ...     OnDemand           GB                    Untagged
# 3   ...     OnDemand           GB                    Untagged
# 4   ...     OnDemand        GB-Mo                     Kemenag
# 5   ...     OnDemand           GB                 Kemendikbud
# 6   ...     OnDemand          Hrs                 Kemendikbud
# 7   ...     OnDemand        GB-Mo                 Kemendikbud
# 8   ...     OnDemand          IOs                 Kemendikbud
# 9   ...     OnDemand           GB                    Untagged
# 10  ...     OnDemand           GB                 Kemendikbud
# 11  ...     OnDemand           GB                    Untagged
# 12  ...     OnDemand     Requests                 Kemendikbud
# 13  ...     OnDemand     Requests                    Untagged
# 14  ...     OnDemand          Hrs                 Kemendikbud
#
#    resource_tags_user_project resource_tags_user_project_owner  \
# 0             PerlindunganPTK                           Minova
# 1                      SIMPKB                           Minova
# 2                      SIMPKB                         Untagged
# 3                       infra                         Untagged
# 4                   SIMPATIKA                        Jayantara
# 5                      SIMPKB                           Minova
# 6                      SIMPKB                           Minova
# 7                      SIMPKB                           Minova
# 8             PerlindunganPTK                           Minova
# 9                       infra                         Untagged
# 10           SekolahPenggerak                           Minova
# 11                        PPG                         Untagged
# 12                     SIMPKB                           Minova
# 13                     SIMPKB                         Untagged
# 14                     SIMPKB                           Minova
#
#    resource_tags_user_tech_owner line_item_unblended_cost day_of_month  \
# 0                            DIP             1.257490e-05            1
# 1                          INFRA             2.142857e-02            1
# 2                       Untagged             5.442000e-07            1
# 3                       Untagged             5.594000e-07            1
# 4                          INFRA             1.190476e-02            1
# 5                          INFRA             0.000000e+00            1
# 6                          INFRA             2.360000e-02            1
# 7                          INFRA             2.976190e-03            1
# 8                          INFRA             1.448000e-05            1
# 9                       Untagged             0.000000e+00            1
# 10                         INFRA             0.000000e+00            1
# 11                      Untagged             3.860000e-08            1
# 12                         INFRA             7.920000e-05            1
# 13                      Untagged             1.500000e-05            1
# 14                         INFRA             1.696000e-01            1
#
#     day_of_week  hour_of_day
# 0             5            0
# 1             5            0
# 2             5            0
# 3             5            0
# 4             5            0
# 5             5            0
# 6             5            0
# 7             5            0
# 8             5            0
# 9             5            0
# 10            5            0
# 11            5            0
# 12            5            0
# 13            5            0
# 14            5            0
#
# [15 rows x 22 columns]

# %%
data.head(1)
# Out:
#    line_item_usage_amount  line_item_normalization_factor  \
# 0                0.001257                             0.0
#
#    line_item_normalized_usage_amount line_item_line_item_type  \
# 0                                0.0                    Usage
#
#                line_item_usage_type line_item_operation  product_region  \
# 0  APS1-DataTransfer-Regional-Bytes       InterZone-Out  ap-southeast-1
#
#         product_to_location     product_from_location product_transfer_type  \
# 0  Asia Pacific (Singapore)  Asia Pacific (Singapore)           IntraRegion
#
#    ... pricing_term pricing_unit resource_tags_user_customer  \
# 0  ...     OnDemand           GB                 Kemendikbud
#
#   resource_tags_user_project resource_tags_user_project_owner  \
# 0            PerlindunganPTK                           Minova
#
#   resource_tags_user_tech_owner line_item_unblended_cost day_of_month  \
# 0                           DIP                 0.000013            1
#
#    day_of_week  hour_of_day
# 0            5            0
#
# [1 rows x 22 columns]

# %%
data["line_item_operation"].value_counts()
# Out:
# line_item_operation
# RunInstances              349398
# CreateVolume              130037
# ReadCostAllocation         86597
# CreateVolume-Gp3           74187
# InterZone-In               66419
#                            ...
# ReadBucketAnalytics            2
# HostedZone                     1
# T3CPUCredits                   1
# CreateGrant                    1
# WriteNotificationProps         1
# Name: count, Length: 136, dtype: int64

# %%
data.shape
# Out:
# (1308761, 22)

# %% [markdown]
# ## 1) Profiling proyek
#
# ### List proyek-proyek yang dikerjakan divisi INFRA

# %%
infra = "INFRA"
cari_infra = data[data['resource_tags_user_tech_owner'] == infra]
value_infra = cari_infra["resource_tags_user_project"].unique().tolist()
print(*value_infra, sep=', ')
# Out:
# SIMPKB, SIMPATIKA, PerlindunganPTK, SekolahPenggerak, BELMAWA, DiklatDIKMENDIKSUS, infra, PPG, Inkubasi, GBGTKPAUDDB, GPO, PPGMUTU, P2GTKMP, TAMASKA, DIKLATKSPS, GuruPenggerak, BACKUP, CDN, praktik-baik, PBS, PPGPRAJAB, dio, LMSERKAM, UKKJ, SMARTVILLAGE, GPK, PPDB-Online, PSP-DIKLAT-IKM-PS, MASOOK, GBGTKPAUD, KEMENSOS, SmartCityNavigator, PPGMUTUPPKS, PPB, MONEV, UKKT, eparkir, GBP3K, PERSONALPTK

# %%
cari_infra[["resource_tags_user_tech_owner", "resource_tags_user_project"]].value_counts()
# Out:
# resource_tags_user_tech_owner  resource_tags_user_project
# INFRA                          SIMPKB                        124312
#                                PPG                            89756
#                                P2GTKMP                        50957
#                                SekolahPenggerak               37754
#                                PPGPRAJAB                      35968
#                                PerlindunganPTK                30502
#                                infra                          30471
#                                DIKLATKSPS                     25556
#                                SIMPATIKA                      24282
#                                GuruPenggerak                  23878
#                                Inkubasi                       21288
#                                DiklatDIKMENDIKSUS             19280
#                                PPGMUTU                        18463
#                                CDN                             6213
#                                PERSONALPTK                     6197
#                                TAMASKA                         5696
#                                UKKJ                            5673
#                                praktik-baik                    5493
#                                GBGTKPAUDDB                     5324
#                                BELMAWA                         3692
#                                KEMENSOS                        2573
#                                dio                             2444
#                                GPO                             2424
#                                PSP-DIKLAT-IKM-PS               2260
#                                MONEV                           1600
#                                GBP3K                           1513
#                                MASOOK                          1290
#                                GBGTKPAUD                       1284
#                                PBS                             1260
#                                GPK                             1260
#                                LMSERKAM                        1260
#                                PPB                             1260
#                                PPGMUTUPPKS                     1170
#                                BACKUP                          1166
#                                UKKT                            1124
#                                SMARTVILLAGE                    1115
#                                eparkir                         1113
#                                PPDB-Online                      744
#                                SmartCityNavigator               744
# Name: count, dtype: int64

# %% [markdown]
# ### List proyek yang dikerjakan divisi DIP

# %%
dip = "DIP"
cari_dip = data[data['resource_tags_user_tech_owner'] == dip]
value_dip = cari_dip["resource_tags_user_project"].unique().tolist()
print(*value_dip, sep=', ')
# Out:
# PerlindunganPTK, CDN, SekolahPenggerak, PPG, SIMPKB, smkpk-rekognisi, DIKLATKSPS, DiklatDIKMENDIKSUS, PPGPRAJAB, Inkubasi, GuruPenggerak, PPGMUTU, P2GTKMP, UKKJ, GBGTKPAUDDB, praktik-baik, SIMPATIKA, PERSONALPTK

# %%
cari_dip[["resource_tags_user_tech_owner", "resource_tags_user_project"]].value_counts()
# Out:
# resource_tags_user_tech_owner  resource_tags_user_project
# DIP                            SIMPKB                        60951
#                                PPG                           15149
#                                SekolahPenggerak              10207
#                                PPGPRAJAB                      9956
#                                GuruPenggerak                  6530
#                                PPGMUTU                        6462
#                                Inkubasi                       6039
#                                CDN                            5617
#                                DIKLATKSPS                     5331
#                                P2GTKMP                        3015
#                                UKKJ                           2625
#                                GBGTKPAUDDB                    2339
#                                DiklatDIKMENDIKSUS             2299
#                                PerlindunganPTK                2293
#                                smkpk-rekognisi                1500
#                                PERSONALPTK                     828
#                                SIMPATIKA                       744
#                                praktik-baik                    744
# Name: count, dtype: int64

# %% [markdown]
# ### List proyek-proyek yang dikerjakan divisi DLA

# %%
dla = "DLA"
cari_dla = data[data['resource_tags_user_tech_owner'] == dla]
value_dla = cari_dla["resource_tags_user_project"].unique().tolist()
print(*value_dla, sep=', ')
# Out:
# PPG, GBGTKPAUDDB, SIMPKB, SIMPATIKA, PPGPRAJAB, Inkubasi, GuruPenggerak, SekolahPenggerak, P2GTKMP, infra

# %%
cari_dla[["resource_tags_user_tech_owner", "resource_tags_user_project"]].value_counts()
# Out:
# resource_tags_user_tech_owner  resource_tags_user_project
# DLA                            SIMPKB                        25588
#                                PPG                           17324
#                                PPGPRAJAB                      5642
#                                SekolahPenggerak               4617
#                                Inkubasi                       4564
#                                GuruPenggerak                  3762
#                                P2GTKMP                        3754
#                                SIMPATIKA                      1543
#                                infra                          1500
#                                GBGTKPAUDDB                     894
# Name: count, dtype: int64

# %% [markdown]
# ### List proyek-proyek yang dikerjakan divisi DPP

# %%
dpp = "DPP"
cari_dpp = data[data['resource_tags_user_tech_owner'] == dpp]
value_dpp = cari_dpp["resource_tags_user_project"].unique().tolist()
print(*value_dpp, sep=', ')
# Out:
# SIMPKB, DiklatDIKMENDIKSUS, SIMPATIKA, MASOOK, PPG, Masook

# %%
cari_dpp[["resource_tags_user_tech_owner", "resource_tags_user_project"]].value_counts()
# Out:
# resource_tags_user_tech_owner  resource_tags_user_project
# DPP                            SIMPKB                        12811
#                                DiklatDIKMENDIKSUS             2616
#                                PPG                            1488
#                                MASOOK                         1327
#                                SIMPATIKA                      1227
#                                Masook                           64
# Name: count, dtype: int64

# %% [markdown]
# ### List proyek-proyek yang dikerjakan divisi Minova

# %%
minova = "Minova"
cari_minova = data[data['resource_tags_user_tech_owner'] == minova]
value_minova = cari_minova["resource_tags_user_project"].unique().tolist()
print(*value_minova, sep=', ')
# Out:
# GuruPenggerak, UKKJ, P2GTMP

# %%
cari_minova[["resource_tags_user_tech_owner", "resource_tags_user_project"]].value_counts()
# Out:
# resource_tags_user_tech_owner  resource_tags_user_project
# Minova                         GuruPenggerak                 1123
#                                P2GTMP                          15
#                                UKKJ                            15
# Name: count, dtype: int64

# %% [markdown]
# ### List proyek-proyek yang dikerjakan divisi DAK

# %%
dak = "DAK"
cari_dak = data[data['resource_tags_user_tech_owner'] == dak]
value_dak = cari_dak["resource_tags_user_project"].unique().tolist()
print(*value_dak, sep=', ')
# Out:
# infra

# %%
cari_dak[["resource_tags_user_tech_owner", "resource_tags_user_project"]].value_counts()
# Out:
# resource_tags_user_tech_owner  resource_tags_user_project
# DAK                            infra                         750
# Name: count, dtype: int64

# %% [markdown]
# ## 2) Profiling operasi AWS
#
# ### List operasi AWS yang dikerjakan divisi INFRA

# %%
infra = "INFRA"
operasi_infra = data[data['resource_tags_user_tech_owner'] == infra]
hasil_operasi_infra = operasi_infra["line_item_operation"].unique().tolist()
print(*hasil_operasi_infra, sep=', ')
# Out:
# CreateVolume-Gp3, CreateVolume, RunInstances, EBS:IO-Write, PublicIP-In, GET, GlacierInstantRetrievalStorage, CreateVolume-Sc1, InterZone-In, Hourly, EBS:IO-Read, ReadCostAllocation, PublicIP-Out, GetObject, CreateVolume-St1, HeadBucket, LoadBalancing:Network, StandardStorage, POST, OPTIONS, InterZone-Out, DeepArchiveS3ObjectOverhead, ObjectTagCount, PutObject, OneZoneIASizeOverhead, OneZoneIAStorage, DELETE, ReadACL, HEAD, PUT, GlacierStorage, DeepArchiveStagingStorage, GlacierObjectOverhead, GlacierS3ObjectOverhead, IntelligentTieringAIAStorage, HeadObject, DeleteObject, PreflightRequest, CreateSnapshot, ReadLocation, ReadBucketPublicAccessBlock, ReadBucketPolicyStatus, ReadBucketPolicy, UploadPart, ListBucket, InitiateMultipartUpload, CompleteMultipartUpload, ReadLogProps, ReadVersioningProps, ReadAccelerate, ReadBucketOwnershipControls, ReadBucketIntelligentTiering, ReadBucketServerSideEncryption, ReadRequestPaymentProps, ReadNotificationProps, WriteCostAllocation, ReadBucketCors, ReadBucketLifecycle, ReadBucketInventory, ReadBucketAnalytics, ReadObjectTagging, ReadBucketReplication

# %%
operasi_infra[["resource_tags_user_tech_owner", "line_item_operation"]].value_counts()
# Out:
# resource_tags_user_tech_owner  line_item_operation
# INFRA                          RunInstances             186538
#                                CreateVolume              77363
#                                EBS:IO-Write              36472
#                                EBS:IO-Read               36387
#                                CreateVolume-Gp3          34110
#                                                          ...
#                                ReadBucketCors                2
#                                ReadBucketLifecycle           2
#                                ReadBucketInventory           2
#                                ReadBucketReplication         2
#                                WriteCostAllocation           2
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# ### List operasi AWS yang dikerjakan divisi DIP

# %%
dip = "DIP"
operasi_dip = data[data['resource_tags_user_tech_owner'] == dip]
hasil_operasi_dip = operasi_dip["line_item_operation"].unique().tolist()
print(*hasil_operasi_dip, sep=', ')
# Out:
# InterZone-Out, CreateVolume, Hourly, RunInstances, EBS:IO-Write, InterZone-In, RunInstances:SV003, EBS:IO-Read, RunInstances:SV002, HeadBucket, PublicIP-Out, CreateVolume-Gp3, PublicIP-In, ReadCostAllocation, StandardStorage, ReadACL, ReadBucketPolicyStatus, ReadLocation, ReadBucketPolicy, ReadBucketPublicAccessBlock, ListBucket, CreateSnapshot, T4GCPUCredits, ReadVersioningProps, ReadBucketOwnershipControls, GetObject

# %%
operasi_dip[["resource_tags_user_tech_owner", "line_item_operation"]].value_counts()
# Out:
# resource_tags_user_tech_owner  line_item_operation
# DIP                            InterZone-Out                  26952
#                                InterZone-In                   26952
#                                RunInstances                   25986
#                                Hourly                         16965
#                                CreateVolume                   16436
#                                EBS:IO-Write                    8268
#                                EBS:IO-Read                     8251
#                                RunInstances:SV003              4773
#                                RunInstances:SV002              2260
#                                CreateVolume-Gp3                2232
#                                PublicIP-In                     1142
#                                PublicIP-Out                    1141
#                                ReadCostAllocation               746
#                                HeadBucket                       373
#                                CreateSnapshot                    30
#                                ReadBucketPolicyStatus            17
#                                ListBucket                        17
#                                ReadACL                           17
#                                ReadBucketPublicAccessBlock       17
#                                StandardStorage                   16
#                                ReadLocation                      15
#                                ReadBucketPolicy                  15
#                                GetObject                          2
#                                ReadBucketOwnershipControls        2
#                                ReadVersioningProps                2
#                                T4GCPUCredits                      2
# Name: count, dtype: int64

# %% [markdown]
# ### List operasi AWS yang dikerjakan divisi DLA

# %%
dla = "DLA"
operasi_dla = data[data['resource_tags_user_tech_owner'] == dla]
hasil_operasi_dla = operasi_dla["line_item_operation"].unique().tolist()
print(*hasil_operasi_dla, sep=', ')
# Out:
# Not Applicable, CreateDBInstance:0018, InterZone-In, CreateDBInstance:0016, InterZone-Out, RunInstances, Hourly, CreateVolume, CreateVolume-Gp3, EBS:IO-Write, EBS:IO-Read, CreateDBInstance, CreateSnapshot

# %%
operasi_dla[["resource_tags_user_tech_owner", "line_item_operation"]].value_counts()
# Out:
# resource_tags_user_tech_owner  line_item_operation
# DLA                            Not Applicable           19102
#                                CreateDBInstance:0018    11654
#                                RunInstances              6492
#                                Hourly                    5620
#                                InterZone-Out             5249
#                                InterZone-In              5249
#                                CreateDBInstance:0016     4124
#                                CreateVolume-Gp3          3720
#                                CreateVolume              2604
#                                EBS:IO-Write              2233
#                                EBS:IO-Read               2226
#                                CreateDBInstance           748
#                                CreateSnapshot             167
# Name: count, dtype: int64

# %%
data["line_item_operation"].value_counts()
# Out:
# line_item_operation
# RunInstances              349398
# CreateVolume              130037
# ReadCostAllocation         86597
# CreateVolume-Gp3           74187
# InterZone-In               66419
#                            ...
# ReadBucketAnalytics            2
# HostedZone                     1
# T3CPUCredits                   1
# CreateGrant                    1
# WriteNotificationProps         1
# Name: count, Length: 136, dtype: int64
